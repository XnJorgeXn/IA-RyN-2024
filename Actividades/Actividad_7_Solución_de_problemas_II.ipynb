# %% [markdown]
# ##**Actividad 7: Solución de problemas II**
# JORGE YAHIR BERLANGA GOMEZ 1963390 N1

# %% [markdown]
# #**PASO 1: IMPORTAR LIBRERIAS**

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn import tree

# %% [markdown]
# #**PASO 2: CARGAR DATOS**

# %%
CANCER = load_breast_cancer()
X = CANCER.data
y = CANCER.target

# %%
CANCER.target_names
# Out:
# array(['malignant', 'benign'], dtype='<U9')

# %% [markdown]
# ##**PASO 3: PROCESAMIENTO DE DATOS**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ##**PASO 4: SELECCION Y ENTRENAMIENTO DE MODELO**

# %%
clf = DecisionTreeClassifier()

# %%
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Exactitud del modelo en el entrenamiento.
train_accuracy = clf.score(X_train, y_train)
print(train_accuracy)
# Out:
# 1.0

# %% [markdown]
# ##**PASO 5: PRUEBA DEL MODELO**

# %%
y_pred = clf.predict(X_test)

# %%
#Predicción 1
print(y_pred[1])
print(y_test[1])
# Out:
# 0
# 0

# %%
#Predicción 2
print(y_pred[20])
print(y_test[20])
# Out:
# 1
# 0

# %%
#Predicción 3
print(y_pred[-1])
print(y_test[-1])
# Out:
# 1
# 1

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("Classification Report:\n", classification_report(y_test, y_pred, target_names=CANCER.target_names))
# Out:
# Accuracy: 0.9181286549707602
# Classification Report:
#                precision    recall  f1-score   support
#
#    malignant       0.87      0.92      0.89        63
#       benign       0.95      0.92      0.93       108
#
#     accuracy                           0.92       171
#    macro avg       0.91      0.92      0.91       171
# weighted avg       0.92      0.92      0.92       171

# %% [markdown]
# ##**PASO 6: VER ARBOL DE DECISIÓN**

# %%
plt.figure(figsize=(20, 15))  # Increase figure size for better resolution
tree.plot_tree(clf, filled=True, feature_names=CANCER.feature_names, class_names=CANCER.target_names)
plt.title("ARBOL DE DECISIÓN DE CANCER DE MAMA")
plt.savefig("decision_tree.png", dpi=300)  # Increase DPI for better resolution
plt.show()
